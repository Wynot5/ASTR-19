# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(0,1,100)

# %%
def exponent(n):
    return np.exp(x)

# %%
y=exponent(x)

# %%
plt.plot(x,y)
plt.xlabel("Time [miliseconds]")
plt.ylabel("Awesomeness B)")

plt.savefig("Journal2-1.pdf",bbox_inches="tight",dpi=600)

plt.show()
